# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
im = cv2.imread("Heightmap/23.013,121.096.png")
print(len(im))
# Out:
# 4000000

# %%
all_height = []
for x in range(2000):
    for y in range(2000):
        pix = im[x][y]
        height = pix[2] + 255 * pix[1] + 255 ** 2 * pix[0]
        all_height.append(height)

# %%
len(all_height)
all_height = np.array(all_height)

# %%
all_height.resize(2000, 2000)

# %%
p = plt.imshow(all_height)
plt.colorbar(p)
plt.show()
