# %%
# %matplotlib inline
import os
import cv2
import numpy
import matplotlib.pyplot as plt

im = cv2.imread("Heightmap/Unity_test.png")

plt.imshow(im)
plt.imshow(im[:,:,2])
cv2.imwrite("gray.png", im[:,:,2])
# Out:
# True
