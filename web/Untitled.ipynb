# %%
from PIL import Image
import numpy as np

# %%
a=Image.open("vtmkel.png")

# %%
import util.split_merge as spl
import matplotlib.pyplot as plt

# %%
c=spl.split(a)

# %%
c[0].mode
# Out:
# 'RGB'

# %%
spl.merge(c)
# Out:
# array([[13262429.79296875, 13764101.38671875, 13764101.38671875, ...,
#          7132372.40625   ,  6643036.96875   ,  6704203.8984375 ],
#        [13575974.5390625 , 14014937.18359375, 14140355.08203125, ...,
#          7132372.40625   ,  6765370.828125  ,  6459536.1796875 ],
#        [12948885.046875  , 13262429.79296875, 13575974.5390625 , ...,
#          7315873.1953125 ,  7071205.4765625 ,  6398369.25      ],
#        ...,
#        [10147129.625     , 10204954.5       , 10147129.625     , ...,
#          8179406.87109375,  8179406.87109375,  7824741.50390625],
#        [10551903.75      , 10667553.5       , 10609728.625     , ...,
#          7588297.92578125,  7647408.8203125 ,  7588297.92578125],
#        [10667553.5       , 11130152.5       , 11187977.375     , ...,
#          6819856.296875  ,  7174521.6640625 ,  7883852.3984375 ]])

# %%
asd=np.zeros((128,128))
asd[0][0]=1

# %%
c[7]=Image.fromarray(asd,'L')

# %%
plt.imshow(spl.merge(c))

# %%
plt.imshow(spl.merge(c))

# %%
c[1]=c[1]*2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-2d8a85f2f9d6> in <module>
# ----> 1 c[1]=c[1]*2
#
# TypeError: unsupported operand type(s) for *: 'Image' and 'int'

# %%
c[1]=c[1].convert('RGB')
